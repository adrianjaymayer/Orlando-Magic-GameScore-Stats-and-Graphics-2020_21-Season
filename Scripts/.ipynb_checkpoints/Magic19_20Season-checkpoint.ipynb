# %% [markdown]
# ### Access libraries that will be used

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from termcolor import colored

# %% [markdown]
# ### Load file into data frame and inspect for adequacy

# %%
pd.set_option('display.max_rows', None)
magic=pd.read_csv(r'P:\pCloud Sync\Magic_20192020_Season.csv')
magic.head()
# Out:
#    LogID First_name Last_name     Age  Pos   Tm   at  Opp WL       Date  ...  \
# 0      1       D.J.  Augustin  32-277    G  ORL  NaN  NOP  W  8/13/2020  ...
# 1      2       Khem     Birch  27-320  C-F  ORL  NaN  NOP  W  8/13/2020  ...
# 2      3       Gary     Clark  25-271    F  ORL  NaN  NOP  W  8/13/2020  ...
# 3      4      James     Ennis  30-043    F  ORL  NaN  NOP  W  8/13/2020  ...
# 4      5     Melvin   Frazier  23-349    G  ORL  NaN  NOP  W  8/13/2020  ...
#
#    DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  BPM
# 0    3    4    6    0    0    2   5   22  19.6  5.7
# 1    1    3    2    1    0    1   2    9   7.1 -6.1
# 2    1    2    0    0    2    1   3    8   4.5 -6.9
# 3    3    4    0    2    0    2   5   16  10.3 -5.7
# 4    3    3    2    1    0    2   0   10   7.3 -3.9
#
# [5 rows x 35 columns]

# %%
magic.tail()
# Out:
#      LogID First_name Last_name     Age  Pos   Tm   at  Opp WL        Date  \
# 749    750   Markelle     Fultz  21-147    G  ORL  NaN  CLE  W  10/23/2019
# 750    751      Aaron    Gordon  24-037    F  ORL  NaN  CLE  W  10/23/2019
# 751    752   Jonathan     Isaac  22-020    F  ORL  NaN  CLE  W  10/23/2019
# 752    753   Terrence      Ross  28-260  F-G  ORL  NaN  CLE  W  10/23/2019
# 753    754     Nikola   Vucevic  28-364    C  ORL  NaN  CLE  W  10/23/2019
#
#      ...  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  BPM
# 749  ...    0    0    6    2    0    3   1   12   8.8  1.7
# 750  ...    2    2    3    2    1    1   4    9   6.2 -1.1
# 751  ...    7    8    2    1    2    2   4    3   3.9 -3.0
# 752  ...    4    4    0    2    0    1   1   10   4.3 -3.4
# 753  ...    9   10    3    1    0    1   0   21  18.1  6.8
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Display data using histogram, swarmplot, and boxplot

# %%
sns.displot(magic['GmSc'])
plt.title("Orlando Magic GameScore Distribution, by Game, 2019-2020 Season", color='mediumblue')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,4))
sns.swarmplot(x="Last_name", y="GmSc", data=magic)
plt.title("Orlando Magic GameScore Distribution, by Game, 2019-2020 Season", color='mediumblue')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.boxplot(x="Last_name", y="GmSc", data=magic)
plt.title("Orlando Magic GameScore Distribution, by player, 2019-2020 Season", color='mediumblue')
plt.show()

# %%
grid = sns.FacetGrid(magic, col = 'Last_name', hue = 'Last_name', col_wrap=5)
grid.map(sns.scatterplot, 'MP', 'GmSc')
grid.add_legend()
print ("\033[1m"+(colored("GameScore versus Minutes Played, by Player", 'blue'))+"\033[0m")
plt.show() 
# Minutes played on x-axis, GameScore on y-axis
# Out:
# GameScore versus Minutes Played, by Player

# %% [markdown]
# ### Calculate each player's average gamescore, standard dev., and quartiles

# %%
print('Average Player GameScore')
magic[['Last_name','GmSc']].\
groupby(['Last_name'], as_index=False).mean()
# Out:
# Average Player GameScore
#           Last_name       GmSc
# 0             Aminu   3.888889
# 1          Augustin   8.607018
# 2             Bamba   5.377419
# 3             Birch   4.858333
# 4   Carter-Williams   6.564444
# 5             Clark   3.250000
# 6             Ennis   6.020000
# 7          Fournier  12.503030
# 8           Frazier   1.489474
# 9             Fultz   9.666667
# 10           Gordon  11.856452
# 11            Isaac  11.138235
# 12           Iwundu   4.521154
# 13        Jefferson   0.811111
# 14          Johnson   1.440000
# 15              Law   0.875000
# 16          Magette   0.737500
# 17             Ross   9.547826
# 18          Vucevic  16.659677

# %%
print('GameScore Standard Deviation by Player')
magic[['Last_name','GmSc']].\
groupby(['Last_name'], as_index=False).std()
# Out:
# GameScore Standard Deviation by Player
#           Last_name      GmSc
# 0             Aminu  5.199196
# 1          Augustin  6.649029
# 2             Bamba  4.596129
# 3             Birch  4.438125
# 4   Carter-Williams  5.307163
# 5             Clark  3.981370
# 6             Ennis  3.827271
# 7          Fournier  6.282453
# 8           Frazier  2.647618
# 9             Fultz  5.027810
# 10           Gordon  6.988319
# 11            Isaac  6.903798
# 12           Iwundu  4.312969
# 13        Jefferson  1.975404
# 14          Johnson  2.466757
# 15              Law  2.233991
# 16          Magette  2.190849
# 17             Ross  6.487173
# 18          Vucevic  6.440050

# %%
print('GameScore Quartile Distribution, by Player')
magic[['Last_name','GmSc']].\
groupby(['Last_name'], as_index=False).quantile([1,0.75,0.5,0.25,0])
# Out:
# GameScore Quartile Distribution, by Player
#                Last_name    GmSc
# 0  1.00            Aminu  15.800
#    0.75            Aminu   6.075
#    0.50            Aminu   2.050
#    0.25            Aminu   0.275
#    0.00            Aminu  -1.600
# 1  1.00         Augustin  24.300
#    0.75         Augustin  11.800
#    0.50         Augustin   8.700
#    0.25         Augustin   3.800
#    0.00         Augustin  -1.600
# 2  1.00            Bamba  17.900
#    0.75            Bamba   8.650
#    0.50            Bamba   4.800
#    0.25            Bamba   1.900
#    0.00            Bamba  -3.000
# 3  1.00            Birch  16.100
#    0.75            Birch   7.100
#    0.50            Birch   4.700
#    0.25            Birch   1.300
#    0.00            Birch  -2.500
# 4  1.00  Carter-Williams  17.600
#    0.75  Carter-Williams  10.200
#    0.50  Carter-Williams   6.600
#    0.25  Carter-Williams   2.000
#    0.00  Carter-Williams  -1.500
# 5  1.00            Clark  13.500
#    0.75            Clark   4.775
#    0.50            Clark   2.450
#    0.25            Clark   0.450
#    0.00            Clark  -1.900
# 6  1.00            Ennis  12.600
#    0.75            Ennis   8.500
#    0.50            Ennis   6.400
#    0.25            Ennis   3.475
#    0.00            Ennis  -0.500
# 7  1.00         Fournier  24.300
#    0.75         Fournier  18.325
#    0.50         Fournier  11.000
#    0.25         Fournier   7.875
#    0.00         Fournier  -0.500
# 8  1.00          Frazier   7.300
#    0.75          Frazier   2.850
#    0.50          Frazier   0.700
#    0.25          Frazier  -0.200
#    0.00          Frazier  -1.400
# 9  1.00            Fultz  25.500
#    0.75            Fultz  12.050
#    0.50            Fultz   8.950
#    0.25            Fultz   6.875
#    0.00            Fultz  -0.700
# 10 1.00           Gordon  30.900
#    0.75           Gordon  15.975
#    0.50           Gordon  10.450
#    0.25           Gordon   7.200
#    0.00           Gordon   0.500
# 11 1.00            Isaac  24.600
#    0.75            Isaac  15.625
#    0.50            Isaac   8.750
#    0.25            Isaac   6.025
#    0.00            Isaac   2.400
# 12 1.00           Iwundu  17.100
#    0.75           Iwundu   6.975
#    0.50           Iwundu   4.200
#    0.25           Iwundu   1.675
#    0.00           Iwundu  -2.700
# 13 1.00        Jefferson   5.200
#    0.75        Jefferson   1.225
#    0.50        Jefferson   0.000
#    0.25        Jefferson  -0.375
#    0.00        Jefferson  -1.800
# 14 1.00          Johnson   5.400
#    0.75          Johnson   3.475
#    0.50          Johnson   0.850
#    0.25          Johnson  -0.700
#    0.00          Johnson  -1.100
# 15 1.00              Law   5.300
#    0.75              Law   1.925
#    0.50              Law   0.150
#    0.25              Law  -0.700
#    0.00              Law  -1.500
# 16 1.00          Magette   4.400
#    0.75          Magette   1.725
#    0.50          Magette   1.250
#    0.25          Magette  -0.775
#    0.00          Magette  -2.800
# 17 1.00             Ross  25.500
#    0.75             Ross  13.200
#    0.50             Ross  10.600
#    0.25             Ross   3.500
#    0.00             Ross  -4.100
# 18 1.00          Vucevic  33.200
#    0.75          Vucevic  20.800
#    0.50          Vucevic  18.100
#    0.25          Vucevic  11.975
#    0.00          Vucevic   2.100
